# %%
l1=[5,7,3,9,10]
total=sum(l1)
print(total,"is the sum")
# Out:
# 34 is the sum

# %%
list=[13,17,9,7,20]
minimum=min(list)
maximum=max(list)
print(minimum," is the minimum number")
print(maximum,"is the maximum number")
# Out:
# 7  is the minimum number
# 20 is the maximum number

# %%
list=[2,3,4,5,6]
e_count=0
o_count=0
for num in list:
  if num%2==0:
    e_count+=1
  else:
    o_count+=1
print(e_count,"are even")
print(o_count,"are odd")
# Out:
# 3 are even
# 2 are odd

# %%
list=[23,46,32,47,23,32]
for num in list:
  for i in range(50):
     if num==i:
         list.remove(i)
print(list)
# Out:
# [46, 47, 32]
